# %% [markdown]
# <a href="https://colab.research.google.com/github/DethSaucin/advanced-machine-learning/blob/main/sethDawson_miles_to_kilometers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Activation, Dense

# %%
miles_q = np.array([4,9,26,47,102,463,500], dtype=float)
kilometers_a = np.array([6,14,41,75,164,745,804], dtype=float)

# %%
for i,c in enumerate(miles_q):
  print(str(c) + " Miles = " + str(kilometers_a[i]) + " Kilometers " )
# Out:
# 4.0 Miles = 6.0 Kilometers
# 9.0 Miles = 14.0 Kilometers
# 26.0 Miles = 41.0 Kilometers
# 47.0 Miles = 75.0 Kilometers
# 102.0 Miles = 164.0 Kilometers
# 463.0 Miles = 745.0 Kilometers
# 500.0 Miles = 804.0 Kilometers

# %%
layer_0 = Dense(units=1, input_shape=[1])
model = Sequential()
model.add(layer_0)
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.Adam(0.1))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(x=miles_q, y=kilometers_a, epochs=500, verbose=True)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 399ms/step - loss: 45501.4648
# Epoch 2/500
# 1/1 [==============================] - 0s 13ms/step - loss: 35015.1602
# Epoch 3/500
# 1/1 [==============================] - 0s 9ms/step - loss: 25947.1465
# Epoch 4/500
# 1/1 [==============================] - 0s 11ms/step - loss: 18310.0215
# Epoch 5/500
# 1/1 [==============================] - 0s 10ms/step - loss: 12097.0537
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 7275.6904
# Epoch 7/500
# 1/1 [==============================] - 0s 11ms/step - loss: 3780.9041
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1508.8766
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 312.8792
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 4.0549
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 359.5213
# Epoch 12/500
# ...

# %%
plt.xlabel('Epoch')
plt.ylabel("Loss")
plt.plot(history.history['loss'])

# %%
print(model.predict([100.0]))
# Out:
# 1/1 [==============================] - 0s 65ms/step
# [[160.60475]]

# %%
print("These are the layer variables: " + str(layer_0.get_weights()))
# The formula is km = 1.6 * M + 0, where weight is 1.6 and bias is 0
# Out:
# These are the layer variables: [array([[1.6090966]], dtype=float32), array([-0.30491596], dtype=float32)]
